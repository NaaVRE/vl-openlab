# %% [markdown]
# ## Design a workflow
# This notebook provides blueprint cells to create a design for your own workflow.
#
# To create a reusable component for your workflow, do the following:
# ...

# %%
# Data explorer
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - datafiles_to_retrieve: List
#   params:
#    - param_url:
#       type: String
#       default_value: "[Fill in the url from which you want to retrieve your data.]"
# ...

# %%
# Data retriever
# ---
# NaaVRE:
#  cell:
#   inputs:
#    - datafiles_to_retrieve: List
#   outputs:
#    - retrieved_datafiles: List
#   params:
#    - param_url:
#       type: String
#       default_value: "[Fill in the url from which you want to retrieve your data.]"
# ...

# %%
# Data filter
# ---
# NaaVRE:
#  cell:
#   inputs:
#    - input_data: String
#   outputs:
#    - filtered_data: String
#   params:
#    - param_years_start:
#       type: Integer
#       default_value: "1870"
#    - param_years_end:
#       type: Integer
#       default_value: "2100"
# ...

# %%
# Model runner
# ---
# NaaVRE:
#  cell:
#   inputs:
#    - preprocessed_data: String
#   outputs:
#    - model_output: String
# ...
